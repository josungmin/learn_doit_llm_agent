# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")  # 환경 변수에서 API 키를 가져옵니다.
client = OpenAI(api_key=api_key)  # OpenAI 클라이언트의 인스턴스를 생성합니다.

# %%
response = client.audio.speech.create(
    model="tts-1-hd",
    voice="alloy",
    input="Hello world! This is a TTS test.",
)

response.write_to_file("hello_world.mp3")

# 재생
import IPython.display as ipd

ipd.Audio("hello_world.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# 다른 목소리
voice = "ash"
mp3_file = f"hello_world_{voice}.mp3"

response = client.audio.speech.create(
    model="tts-1-hd",
    voice=voice,
    input=f"Hello world! I'm {voice}. This is a TTS test.",
)

response.write_to_file(mp3_file)

# 재생
import IPython.display as ipd

ipd.Audio(mp3_file)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import json

# json 파일 열기
with open('data/images/image_quiz_eng.json', 'r', encoding='utf-8') as f:
    eng_dict = json.load(f)

eng_dict
# Out:
# [{'no': 1,
#   'eng': 'Which of the following descriptions of the image is incorrect?  \n- (1) An anime-style character wearing yellow and orange clothing is shown.  \n- (2) The character is holding a sword with both hands.  \n- (3) Bright lightning and light effects appear around the character.  \n- (4) The character is wearing a blue hat.',
#   'img': '귀멸의칼날_젠이츠.png'},
#  {'no': 2,
#   'eng': 'Which of the following descriptions of the image is incorrect?  \n- (1) A giraffe is standing behind the other animals.  \n- (2) A lion is lying in the foreground.  \n- (3) Several bees are flying around the animals.  \n- (4) An elephant is grazing beside the lion.',
#   'img': '틀린그림찾기_1.png'},
#  {'no': 3,
#   'eng': 'Which of the following descriptions of the image is incorrect?  \n- (1) A giraffe is standing behind the lion.  \n- (2) The lion is sitting in a tree.  \n- (3) Two bears are around the lion.  \n- (4) There is a snake in the lower left part of the picture.',
#   'img': '틀린그림찾기_2.png'}]

# %%
voices = ['alloy', 'ash', 'coral', 'echo', 'fable', 'onyx', 'nova', 'sage' , 'shimmer']

for q in eng_dict:
    no = q['no']
    quiz = q['eng']
    quiz = quiz.replace("- (1)", "- One.\t")
    quiz = quiz.replace("- (2)", "- Two.\t")
    quiz = quiz.replace("- (3)", "- Three.\t")
    quiz = quiz.replace("- (4)", "- Four.\t")    

    print(no, quiz)
    
    voice = voices[no % len(voices)] # 문제 개수를 목소리 개수로 나눈 나머지 값으로 선택  

    response = client.audio.speech.create(
        model="tts-1-hd",
        voice=voice,
        input=f'#{no}. {quiz}',
    )

    response.write_to_file(f"data/audio/{no}.mp3")
# Out:
# 1 Which of the following descriptions of the image is incorrect?
# - One.	 An anime-style character wearing yellow and orange clothing is shown.
# - Two.	 The character is holding a sword with both hands.
# - Three.	 Bright lightning and light effects appear around the character.
# - Four.	 The character is wearing a blue hat.
# 2 Which of the following descriptions of the image is incorrect?
# - One.	 A giraffe is standing behind the other animals.
# - Two.	 A lion is lying in the foreground.
# - Three.	 Several bees are flying around the animals.
# - Four.	 An elephant is grazing beside the lion.
# 3 Which of the following descriptions of the image is incorrect?
# - One.	 A giraffe is standing behind the lion.
# - Two.	 The lion is sitting in a tree.
# - Three.	 Two bears are around the lion.
# - Four.	 There is a snake in the lower left part of the picture.

# %%
ipd.Audio(f"data/audio/1.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
